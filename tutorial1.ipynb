# %% [markdown]
# ## Sequence Types 2

# %% [markdown]
# 1+2

# %%
x, y = 2, 3

# %%
x
# Out:
# 2

# %%
y
# Out:
# 3

# %%
tu = (23, 'abc', 4.56, (2,3), 'def')

# %%
tu[0]
# Out:
# 23

# %%
tu[1]
# Out:
# 'abc'

# %%
li = ["abc", 34, 4.34, 23]

# %%
li[0]
# Out:
# 'abc'

# %%
li[1]
# Out:
# 34

# %%
li[2]
# Out:
# 4.34

# %%
int x=2;
float y= 2.3;
string msg = 'message';

c, java, python

# %%
st = """This is a multi-line
string that uses triple quotes."""

# %%
st
# Out:
# 'This is a multi-line\nstring that uses triple quotes'

# %%
print(st)
# Out:
# This is a multi-line
# string that uses triple quotes

# %%
print(li)
# Out:
# ['abc', 34, 4.34, 23]

# %%
li[-2]
# Out:
# 4.34

# %%
li[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-eaafe881b5d5> in <module>
# ----> 1 li[4]
#
# IndexError: list index out of range

# %%
tu[0]
# Out:
# 23

# %%
tu[1]
# Out:
# 'abc'

# %%
tu[2]
# Out:
# 4.56

# %%
tu[-1]
# Out:
# 'def'

# %%
tu[4]
# Out:
# 'def'

# %%
tu[1:4]
# Out:
# ('abc', 4.56, (2, 3))

# %%
tu[1:4:2]
# Out:
# ('abc', (2, 3))

# %%
tu[:4]
# Out:
# (23, 'abc', 4.56, (2, 3))

# %%
tu[2:]
# Out:
# (4.56, (2, 3), 'def')

# %%
tu
# Out:
# (23, 'abc', 4.56, (2, 3), 'def')

# %%
tu[:]
# Out:
# (23, 'abc', 4.56, (2, 3), 'def')

# %%
tu1=tu

# %%
print(tu1)
# Out:
# (23, 'abc', 4.56, (2, 3), 'def')

# %%
tu1[0]=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-adc0b7b1998e> in <module>
# ----> 1 tu1[0]=1
#
# TypeError: 'tuple' object does not support item assignment

# %%
li = [23, 'abc', 4.56, (2,3), 'def'] --> mutable
# Out:
#   File "<ipython-input-40-49ce04ddfefc>", line 1
#     li = [23, 'abc', 4.56, (2,3), 'def'] --> mutable
#                                           ^
# SyntaxError: invalid syntax

# %%
print(li)
# Out:
# [1, 'abc', 4.56, (2, 3), 'def']

# %%
li[0]=1

# %%
print(li)
# Out:
# [1, 'abc', 4.56, (2, 3), 'def']
